# %% [markdown]
# # AAC Siegfried Analysis
#
# This notebook explores some of the research questions arising following the analysis of the British Library Asian and African Studies collection metadata with [Siegfried](https://www.itforarchivists.com/siegfried/)
#
# During August 2019, a total of 69.33 TB of material was analysed. The combined DROID-style output for TIFF files from Siegfried resulting from this analysis is available in `CombinedOutput_2019-09-03_allTiffs_parentDirs_folderCount.csv` - the original output from Siegfried has been augmented to include only TIFF files and the parent directory of each file scanned. The `FolderCount` field was added in order to find the number of files present in each folder.
#
# An important note: the following pandas dataframes only exist within memory and do not persist without writing them to a file!

# %% [markdown]
# ## Setting up an analysis environment
# ***This section describes setting up a python environemt with the pip package manager - others are available***
# ### You will need:
# - Python 3 (already installed if you can see this!)
# - Pip package manager.
#
# At the very minimum you will probably need to have installed the pandas and numpy python modules. Others, such as matplotlib, will be necessary for any data visualisation.
#
# Install pip with:

# %%
#curl https://bootstrap.pypa.io/get-pip.py -o get-pip.py
#python get-pip.py

# %% [markdown]
# Install packages with

# %%
#pip install numpy pandas #and any others...

# %% [markdown]
# Import the necessary python modules:

# %%
import pandas as pd 
import numpy as np
pd.set_option('display.max_columns', None)

# %% [markdown]
# Load the csv file as a pandas DataFrame and print a few rows:

# %%
allData=pd.read_csv("CombinedOutput_2019-09-03_allTiffs_parentDirs_folderCount.csv",sep=',')
allData.head(5)
# Out:
#    ID  PARENT_ID                                                URI  \
# 0   1        NaN  file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 1   2        NaN  file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 2   3        NaN  file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 3   4        NaN  file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 4   5        NaN  file:///P12L-NAS5/Persian%20Digitisation/Grenv...
#
#                                            FILE_PATH                     NAME  \
# 0  \\P12L-NAS5\Persian Digitisation\Grenville xli...  grenville_xli_f001r.tif
# 1  \\P12L-NAS5\Persian Digitisation\Grenville xli...  grenville_xli_f001v.tif
# 2  \\P12L-NAS5\Persian Digitisation\Grenville xli...  grenville_xli_f002r.tif
# 3  \\P12L-NAS5\Persian Digitisation\Grenville xli...  grenville_xli_f002v.tif
# 4  \\P12L-NAS5\Persian Digitisation\Grenville xli...  grenville_xli_f003r.tif
#
#       METHOD STATUS        SIZE  TYPE  EXT              LAST_MODIFIED  \
# 0  Signature   Done  90714782.0  File  tif  2013-04-22T10:40:14+01:00
# 1  Signature   Done  85295734.0  File  tif  2013-04-25T10:57:52+01:00
# 2  Signature   Done  89390472.0  File  tif  2013-04-22T10:40:32+01:00
# 3  Signature   Done  82452820.0  File  tif  2013-04-22T11:11:26+01:00
# 4  Signature   Done  86180984.0  File  tif  2013-04-22T10:40:44+01:00
#
#    EXTENSION_MISMATCH                                        SHA256_HASH  \
# 0               False  8a0a01aa68bdf8e39604b747829f4c7fa38755ce335c3f...
# 1               False  256f682db10c7b57f5aaf4257bfa8220388383e8d835d2...
# 2               False  9320ca9074e19ad5537d1dc4b78d3574916c4d56bcc5f4...
# 3               False  a71db4bbd406b34f7e407240030a5eb82d72955ecc6e27...
# 4               False  9429574137662b13efa5256290a75982f9c3ec60245233...
#
#    FORMAT_COUNT       PUID   MIME_TYPE  \
# 0           1.0  x-fmt/387  image/tiff
# 1           1.0  x-fmt/387  image/tiff
# 2           1.0  x-fmt/387  image/tiff
# 3           1.0  x-fmt/387  image/tiff
# 4           1.0  x-fmt/387  image/tiff
#
#                                      FORMAT_NAME  FORMAT_VERSION  \
# 0  Exchangeable Image File Format (Uncompressed)             2.2
# 1  Exchangeable Image File Format (Uncompressed)             2.2
# 2  Exchangeable Image File Format (Uncompressed)             2.2
# 3  Exchangeable Image File Format (Uncompressed)             2.2
# 4  Exchangeable Image File Format (Uncompressed)             2.2
#
#                                           PARENT_DIR  FolderCount
# 0  \\P12L-NAS5\Persian Digitisation\Grenville xli...            1
# 1  \\P12L-NAS5\Persian Digitisation\Grenville xli...            1
# 2  \\P12L-NAS5\Persian Digitisation\Grenville xli...            1
# 3  \\P12L-NAS5\Persian Digitisation\Grenville xli...            1
# 4  \\P12L-NAS5\Persian Digitisation\Grenville xli...            1

# %% [markdown]
# Remove `NaN` (Not A Number) null values and replace them with an empty string "" to enable some string comparisons later down the line

# %%
allData=allData.replace(np.nan,"")
allData.head(5)
# Out:
#    ID PARENT_ID                                                URI  \
# 0   1            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 1   2            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 2   3            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 3   4            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 4   5            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
#
#                                            FILE_PATH                     NAME  \
# 0  \\P12L-NAS5\Persian Digitisation\Grenville xli...  grenville_xli_f001r.tif
# 1  \\P12L-NAS5\Persian Digitisation\Grenville xli...  grenville_xli_f001v.tif
# 2  \\P12L-NAS5\Persian Digitisation\Grenville xli...  grenville_xli_f002r.tif
# 3  \\P12L-NAS5\Persian Digitisation\Grenville xli...  grenville_xli_f002v.tif
# 4  \\P12L-NAS5\Persian Digitisation\Grenville xli...  grenville_xli_f003r.tif
#
#       METHOD STATUS        SIZE  TYPE  EXT              LAST_MODIFIED  \
# 0  Signature   Done  90714782.0  File  tif  2013-04-22T10:40:14+01:00
# 1  Signature   Done  85295734.0  File  tif  2013-04-25T10:57:52+01:00
# 2  Signature   Done  89390472.0  File  tif  2013-04-22T10:40:32+01:00
# 3  Signature   Done  82452820.0  File  tif  2013-04-22T11:11:26+01:00
# 4  Signature   Done  86180984.0  File  tif  2013-04-22T10:40:44+01:00
#
#    EXTENSION_MISMATCH                                        SHA256_HASH  \
# 0               False  8a0a01aa68bdf8e39604b747829f4c7fa38755ce335c3f...
# 1               False  256f682db10c7b57f5aaf4257bfa8220388383e8d835d2...
# 2               False  9320ca9074e19ad5537d1dc4b78d3574916c4d56bcc5f4...
# 3               False  a71db4bbd406b34f7e407240030a5eb82d72955ecc6e27...
# 4               False  9429574137662b13efa5256290a75982f9c3ec60245233...
#
#    FORMAT_COUNT       PUID   MIME_TYPE  \
# 0           1.0  x-fmt/387  image/tiff
# 1           1.0  x-fmt/387  image/tiff
# 2           1.0  x-fmt/387  image/tiff
# 3           1.0  x-fmt/387  image/tiff
# 4           1.0  x-fmt/387  image/tiff
#
#                                      FORMAT_NAME FORMAT_VERSION  \
# 0  Exchangeable Image File Format (Uncompressed)            2.2
# 1  Exchangeable Image File Format (Uncompressed)            2.2
# 2  Exchangeable Image File Format (Uncompressed)            2.2
# 3  Exchangeable Image File Format (Uncompressed)            2.2
# 4  Exchangeable Image File Format (Uncompressed)            2.2
#
#                                           PARENT_DIR  FolderCount
# 0  \\P12L-NAS5\Persian Digitisation\Grenville xli...            1
# 1  \\P12L-NAS5\Persian Digitisation\Grenville xli...            1
# 2  \\P12L-NAS5\Persian Digitisation\Grenville xli...            1
# 3  \\P12L-NAS5\Persian Digitisation\Grenville xli...            1
# 4  \\P12L-NAS5\Persian Digitisation\Grenville xli...            1

# %% [markdown]
# ## Duplicate Analysis

# %% [markdown]
# Firstly, find exact duplicates by SHA256 hash match. Read this as "show allData where duplicate entries are found in the `SHA256_HASH` column". The [pandas documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) shows that the `duplicated` member function defaults to marking duplicates as `True` except for the first occurrence. If you want to include the "original" file in addition to any duplicates, include `keep=False` in the function call. Using the default behaviour, as below, shows only "pure duplicates" and omits the original file.

# %%
onlyDuplicates=allData[allData.duplicated(subset="SHA256_HASH")]
onlyDuplicates
# Out:
#               ID PARENT_ID                                                URI  \
# 16637      16638            file:///P12L-NAS5/Persian%20Digitisation/Or%20...
# 33491      33499            file:///P12L-NAS5/Preservation%20Digitisation%...
# 33492      33500            file:///P12L-NAS5/Preservation%20Digitisation%...
# 33493      33501            file:///P12L-NAS5/Preservation%20Digitisation%...
# 33494      33502            file:///P12L-NAS5/Preservation%20Digitisation%...
# ...          ...       ...                                                ...
# 1275916  1328311            file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
# 1275917  1328312            file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
# 1275918  1328313            file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
# 1275919  1328314            file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
# 1275920  1328315            file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
#
#                                                  FILE_PATH  \
# 16637    \\P12L-NAS5\Persian Digitisation\Or 5302\or_53...
# 33491    \\P12L-NAS5\Preservation Digitisation Bids 201...
# 33492    \\P12L-NAS5\Preservation Digitisation Bids 201...
# 33493    \\P12L-NAS5\Preservation Digitisation Bids 201...
# 33494    \\P12L-NAS5\Preservation Digitisation Bids 201...
# ...                                                    ...
# 1275916  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275917  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275918  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275919  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275920  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
#
#                            NAME     METHOD STATUS         SIZE  TYPE  EXT  \
# 16637         or_5302_f_1~r.tif  Signature   Done  103677788.0  File  tif
# 33491    add_ms_14373_f001r.tif  Signature   Done  101107818.0  File  tif
# 33492    add_ms_14373_f001v.tif  Signature   Done   95056216.0  File  tif
# 33493    add_ms_14373_f002r.tif  Signature   Done  101107818.0  File  tif
# 33494    add_ms_14373_f002v.tif  Signature   Done   95056216.0  File  tif
# ...                         ...        ...    ...          ...   ...  ...
# 1275916      or_7458_fbrigr.tif  Signature   Done   66538396.0  File  tif
# 1275917      or_7458_fbrigv.tif  Signature   Done   66538396.0  File  tif
# 1275918       or_7458_fbspi.tif  Signature   Done   39485948.0  File  tif
# 1275919     or_7458_fse002r.tif  Signature   Done   66538396.0  File  tif
# 1275920     or_7458_fse002v.tif  Signature   Done   66538396.0  File  tif
#
#                      LAST_MODIFIED  EXTENSION_MISMATCH  \
# 16637    2013-06-11T09:44:37+01:00               False
# 33491    2017-08-14T11:35:20+01:00               False
# 33492    2017-08-14T11:40:32+01:00               False
# 33493    2017-08-14T11:35:28+01:00               False
# 33494    2017-08-14T11:40:34+01:00               False
# ...                            ...                 ...
# 1275916       2007-01-04T00:42:21Z               False
# 1275917       2007-01-04T00:44:31Z               False
# 1275918       2007-01-04T00:46:28Z               False
# 1275919       2007-01-04T00:38:13Z               False
# 1275920       2007-01-04T00:40:08Z               False
#
#                                                SHA256_HASH  FORMAT_COUNT  \
# 16637    edc98acdd02aeb5f113c8ccab68e17f4d11a0012d98378...           1.0
# 33491    e8d915613378b78a5fa00db97a69acecfc1be50d74bfcb...           1.0
# 33492    50ba9310a26f3d72eef400eee3c0464c2b06ac8edbdec0...           1.0
# 33493    c0479b980e3d9d68be8f9f246ef51d1d47d822ab774b17...           1.0
# 33494    f2de0c0da8f67dbf34b4fb1bc6b2849eaa1f297e60ad87...           1.0
# ...                                                    ...           ...
# 1275916  0c9f2baf3dd8477bd20327df6f0d3733c8392878512110...           1.0
# 1275917  8cc44b99495ca7e7767600d1ba26edb385fa8232826978...           1.0
# 1275918  7b5a24a82b9d25e08e4884dea94e1b06e9c5ee6cdebfc8...           1.0
# 1275919  eea8c2788a5d8e907c3e99bf5a833ac3c6fae4be96780a...           1.0
# 1275920  0a3bc9d298bc5f89070117f5f427f44f4ef0c1b779bf0c...           1.0
#
#               PUID   MIME_TYPE                                    FORMAT_NAME  \
# 16637    x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
# 33491      fmt/353  image/tiff                       Tagged Image File Format
# 33492      fmt/353  image/tiff                       Tagged Image File Format
# 33493      fmt/353  image/tiff                       Tagged Image File Format
# 33494      fmt/353  image/tiff                       Tagged Image File Format
# ...            ...         ...                                            ...
# 1275916  x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
# 1275917  x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
# 1275918  x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
# 1275919  x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
# 1275920  x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
#
#         FORMAT_VERSION                                         PARENT_DIR  \
# 16637              2.2   \\P12L-NAS5\Persian Digitisation\Or 5302\or_5302
# 33491                   \\P12L-NAS5\Preservation Digitisation Bids 201...
# 33492                   \\P12L-NAS5\Preservation Digitisation Bids 201...
# 33493                   \\P12L-NAS5\Preservation Digitisation Bids 201...
# 33494                   \\P12L-NAS5\Preservation Digitisation Bids 201...
# ...                ...                                                ...
# 1275916            2.2  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275917            2.2  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275918            2.2  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275919            2.2  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275920            2.2  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
#
#          FolderCount
# 16637              1
# 33491              1
# 33492              1
# 33493              1
# 33494              1
# ...              ...
# 1275916            1
# 1275917            1
# 1275918            1
# 1275919            1
# 1275920            1
#
# [85119 rows x 20 columns]

# %% [markdown]
# Results in 85119 pure duplicates found. Finding more information about the duplicates:

# %%
totalDuplicateSize=onlyDuplicates['SIZE'].sum()/(1024**4) # Siegfried returns size in bytes, so display size in TB
print("Total size of duplicates: {} TB".format(totalDuplicateSize))
# Out:
# Total size of duplicates: 5.383706840476407 TB

# %%
duplicateFileList=onlyDuplicates.index.to_list()

# %% [markdown]
# Now we'd like to identify files in the Siegfried output with exactly duplicates. We don't know (yet) which file is the original, so we need to find all files with exact hash matches, rather than setting aside an 'original' set.

# %%
duplicatesAndOriginals=allData[allData.duplicated(subset="SHA256_HASH",keep=False)]
duplicatesAndOriginals
# Out:
#               ID PARENT_ID                                                URI  \
# 0              1            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 1              2            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 2              3            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 3              4            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 4              5            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# ...          ...       ...                                                ...
# 1275916  1328311            file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
# 1275917  1328312            file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
# 1275918  1328313            file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
# 1275919  1328314            file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
# 1275920  1328315            file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
#
#                                                  FILE_PATH  \
# 0        \\P12L-NAS5\Persian Digitisation\Grenville xli...
# 1        \\P12L-NAS5\Persian Digitisation\Grenville xli...
# 2        \\P12L-NAS5\Persian Digitisation\Grenville xli...
# 3        \\P12L-NAS5\Persian Digitisation\Grenville xli...
# 4        \\P12L-NAS5\Persian Digitisation\Grenville xli...
# ...                                                    ...
# 1275916  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275917  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275918  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275919  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275920  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
#
#                             NAME     METHOD STATUS        SIZE  TYPE  EXT  \
# 0        grenville_xli_f001r.tif  Signature   Done  90714782.0  File  tif
# 1        grenville_xli_f001v.tif  Signature   Done  85295734.0  File  tif
# 2        grenville_xli_f002r.tif  Signature   Done  89390472.0  File  tif
# 3        grenville_xli_f002v.tif  Signature   Done  82452820.0  File  tif
# 4        grenville_xli_f003r.tif  Signature   Done  86180984.0  File  tif
# ...                          ...        ...    ...         ...   ...  ...
# 1275916       or_7458_fbrigr.tif  Signature   Done  66538396.0  File  tif
# 1275917       or_7458_fbrigv.tif  Signature   Done  66538396.0  File  tif
# 1275918        or_7458_fbspi.tif  Signature   Done  39485948.0  File  tif
# 1275919      or_7458_fse002r.tif  Signature   Done  66538396.0  File  tif
# 1275920      or_7458_fse002v.tif  Signature   Done  66538396.0  File  tif
#
#                      LAST_MODIFIED  EXTENSION_MISMATCH  \
# 0        2013-04-22T10:40:14+01:00               False
# 1        2013-04-25T10:57:52+01:00               False
# 2        2013-04-22T10:40:32+01:00               False
# 3        2013-04-22T11:11:26+01:00               False
# 4        2013-04-22T10:40:44+01:00               False
# ...                            ...                 ...
# 1275916       2007-01-04T00:42:21Z               False
# 1275917       2007-01-04T00:44:31Z               False
# 1275918       2007-01-04T00:46:28Z               False
# 1275919       2007-01-04T00:38:13Z               False
# 1275920       2007-01-04T00:40:08Z               False
#
#                                                SHA256_HASH  FORMAT_COUNT  \
# 0        8a0a01aa68bdf8e39604b747829f4c7fa38755ce335c3f...           1.0
# 1        256f682db10c7b57f5aaf4257bfa8220388383e8d835d2...           1.0
# 2        9320ca9074e19ad5537d1dc4b78d3574916c4d56bcc5f4...           1.0
# 3        a71db4bbd406b34f7e407240030a5eb82d72955ecc6e27...           1.0
# 4        9429574137662b13efa5256290a75982f9c3ec60245233...           1.0
# ...                                                    ...           ...
# 1275916  0c9f2baf3dd8477bd20327df6f0d3733c8392878512110...           1.0
# 1275917  8cc44b99495ca7e7767600d1ba26edb385fa8232826978...           1.0
# 1275918  7b5a24a82b9d25e08e4884dea94e1b06e9c5ee6cdebfc8...           1.0
# 1275919  eea8c2788a5d8e907c3e99bf5a833ac3c6fae4be96780a...           1.0
# 1275920  0a3bc9d298bc5f89070117f5f427f44f4ef0c1b779bf0c...           1.0
#
#               PUID   MIME_TYPE                                    FORMAT_NAME  \
# 0        x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
# 1        x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
# 2        x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
# 3        x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
# 4        x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
# ...            ...         ...                                            ...
# 1275916  x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
# 1275917  x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
# 1275918  x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
# 1275919  x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
# 1275920  x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
#
#         FORMAT_VERSION                                         PARENT_DIR  \
# 0                  2.2  \\P12L-NAS5\Persian Digitisation\Grenville xli...
# 1                  2.2  \\P12L-NAS5\Persian Digitisation\Grenville xli...
# 2                  2.2  \\P12L-NAS5\Persian Digitisation\Grenville xli...
# 3                  2.2  \\P12L-NAS5\Persian Digitisation\Grenville xli...
# 4                  2.2  \\P12L-NAS5\Persian Digitisation\Grenville xli...
# ...                ...                                                ...
# 1275916            2.2  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275917            2.2  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275918            2.2  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275919            2.2  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275920            2.2  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
#
#          FolderCount
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 1275916            1
# 1275917            1
# 1275918            1
# 1275919            1
# 1275920            1
#
# [160035 rows x 20 columns]

# %% [markdown]
# Now create a column in the original DataFrame to denote if a file is a duplicate:

# %%
allData['IsDuplicate']=False

# %% [markdown]
# You can check if this column has been added to the DataFrame with:

# %%
allData.columns
# Out:
# Index(['ID', 'PARENT_ID', 'URI', 'FILE_PATH', 'NAME', 'METHOD', 'STATUS',
#        'SIZE', 'TYPE', 'EXT', 'LAST_MODIFIED', 'EXTENSION_MISMATCH',
#        'SHA256_HASH', 'FORMAT_COUNT', 'PUID', 'MIME_TYPE', 'FORMAT_NAME',
#        'FORMAT_VERSION', 'PARENT_DIR', 'FolderCount', 'IsDuplicate'],
#       dtype='object')

# %% [markdown]
# Turn the ID column from the duplicate dataframe into a python list

# %%
duplicateIDList=duplicatesAndOriginals.ID.to_list()

# %% [markdown]
# Locate these IDs in the main dataframe and set their `IsDuplicate` value to `True`

# %%
allData.loc[allData['ID'].isin(duplicateIDList),'IsDuplicate']=True

# %% [markdown]
# Check things have worked:

# %%
allData[allData['IsDuplicate']]
# Out:
#               ID PARENT_ID                                                URI  \
# 0              1            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 1              2            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 2              3            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 3              4            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 4              5            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# ...          ...       ...                                                ...
# 1275916  1328311            file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
# 1275917  1328312            file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
# 1275918  1328313            file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
# 1275919  1328314            file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
# 1275920  1328315            file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
#
#                                                  FILE_PATH  \
# 0        \\P12L-NAS5\Persian Digitisation\Grenville xli...
# 1        \\P12L-NAS5\Persian Digitisation\Grenville xli...
# 2        \\P12L-NAS5\Persian Digitisation\Grenville xli...
# 3        \\P12L-NAS5\Persian Digitisation\Grenville xli...
# 4        \\P12L-NAS5\Persian Digitisation\Grenville xli...
# ...                                                    ...
# 1275916  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275917  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275918  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275919  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275920  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
#
#                             NAME     METHOD STATUS        SIZE  TYPE  EXT  \
# 0        grenville_xli_f001r.tif  Signature   Done  90714782.0  File  tif
# 1        grenville_xli_f001v.tif  Signature   Done  85295734.0  File  tif
# 2        grenville_xli_f002r.tif  Signature   Done  89390472.0  File  tif
# 3        grenville_xli_f002v.tif  Signature   Done  82452820.0  File  tif
# 4        grenville_xli_f003r.tif  Signature   Done  86180984.0  File  tif
# ...                          ...        ...    ...         ...   ...  ...
# 1275916       or_7458_fbrigr.tif  Signature   Done  66538396.0  File  tif
# 1275917       or_7458_fbrigv.tif  Signature   Done  66538396.0  File  tif
# 1275918        or_7458_fbspi.tif  Signature   Done  39485948.0  File  tif
# 1275919      or_7458_fse002r.tif  Signature   Done  66538396.0  File  tif
# 1275920      or_7458_fse002v.tif  Signature   Done  66538396.0  File  tif
#
#          ... EXTENSION_MISMATCH  \
# 0        ...              False
# 1        ...              False
# 2        ...              False
# 3        ...              False
# 4        ...              False
# ...      ...                ...
# 1275916  ...              False
# 1275917  ...              False
# 1275918  ...              False
# 1275919  ...              False
# 1275920  ...              False
#
#                                                SHA256_HASH FORMAT_COUNT  \
# 0        8a0a01aa68bdf8e39604b747829f4c7fa38755ce335c3f...          1.0
# 1        256f682db10c7b57f5aaf4257bfa8220388383e8d835d2...          1.0
# 2        9320ca9074e19ad5537d1dc4b78d3574916c4d56bcc5f4...          1.0
# 3        a71db4bbd406b34f7e407240030a5eb82d72955ecc6e27...          1.0
# 4        9429574137662b13efa5256290a75982f9c3ec60245233...          1.0
# ...                                                    ...          ...
# 1275916  0c9f2baf3dd8477bd20327df6f0d3733c8392878512110...          1.0
# 1275917  8cc44b99495ca7e7767600d1ba26edb385fa8232826978...          1.0
# 1275918  7b5a24a82b9d25e08e4884dea94e1b06e9c5ee6cdebfc8...          1.0
# 1275919  eea8c2788a5d8e907c3e99bf5a833ac3c6fae4be96780a...          1.0
# 1275920  0a3bc9d298bc5f89070117f5f427f44f4ef0c1b779bf0c...          1.0
#
#               PUID   MIME_TYPE                                    FORMAT_NAME  \
# 0        x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
# 1        x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
# 2        x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
# 3        x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
# 4        x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
# ...            ...         ...                                            ...
# 1275916  x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
# 1275917  x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
# 1275918  x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
# 1275919  x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
# 1275920  x-fmt/387  image/tiff  Exchangeable Image File Format (Uncompressed)
#
#         FORMAT_VERSION                                         PARENT_DIR  \
# 0                  2.2  \\P12L-NAS5\Persian Digitisation\Grenville xli...
# 1                  2.2  \\P12L-NAS5\Persian Digitisation\Grenville xli...
# 2                  2.2  \\P12L-NAS5\Persian Digitisation\Grenville xli...
# 3                  2.2  \\P12L-NAS5\Persian Digitisation\Grenville xli...
# 4                  2.2  \\P12L-NAS5\Persian Digitisation\Grenville xli...
# ...                ...                                                ...
# 1275916            2.2  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275917            2.2  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275918            2.2  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275919            2.2  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1275920            2.2  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
#
#         FolderCount  IsDuplicate
# 0                 1         True
# 1                 1         True
# 2                 1         True
# 3                 1         True
# 4                 1         True
# ...             ...          ...
# 1275916           1         True
# 1275917           1         True
# 1275918           1         True
# 1275919           1         True
# 1275920           1         True
#
# [160035 rows x 21 columns]

# %%
allData.head(10)
# Out:
#    ID PARENT_ID                                                URI  \
# 0   1            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 1   2            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 2   3            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 3   4            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 4   5            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 5   6            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 6   7            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 7   8            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 8   9            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 9  10            file:///P12L-NAS5/Persian%20Digitisation/Grenv...
#
#                                            FILE_PATH                     NAME  \
# 0  \\P12L-NAS5\Persian Digitisation\Grenville xli...  grenville_xli_f001r.tif
# 1  \\P12L-NAS5\Persian Digitisation\Grenville xli...  grenville_xli_f001v.tif
# 2  \\P12L-NAS5\Persian Digitisation\Grenville xli...  grenville_xli_f002r.tif
# 3  \\P12L-NAS5\Persian Digitisation\Grenville xli...  grenville_xli_f002v.tif
# 4  \\P12L-NAS5\Persian Digitisation\Grenville xli...  grenville_xli_f003r.tif
# 5  \\P12L-NAS5\Persian Digitisation\Grenville xli...  grenville_xli_f003v.tif
# 6  \\P12L-NAS5\Persian Digitisation\Grenville xli...  grenville_xli_f004r.tif
# 7  \\P12L-NAS5\Persian Digitisation\Grenville xli...  grenville_xli_f004v.tif
# 8  \\P12L-NAS5\Persian Digitisation\Grenville xli...  grenville_xli_f005r.tif
# 9  \\P12L-NAS5\Persian Digitisation\Grenville xli...  grenville_xli_f005v.tif
#
#       METHOD STATUS        SIZE  TYPE  EXT  ... EXTENSION_MISMATCH  \
# 0  Signature   Done  90714782.0  File  tif  ...              False
# 1  Signature   Done  85295734.0  File  tif  ...              False
# 2  Signature   Done  89390472.0  File  tif  ...              False
# 3  Signature   Done  82452820.0  File  tif  ...              False
# 4  Signature   Done  86180984.0  File  tif  ...              False
# 5  Signature   Done  82452820.0  File  tif  ...              False
# 6  Signature   Done  86375264.0  File  tif  ...              False
# 7  Signature   Done  82452820.0  File  tif  ...              False
# 8  Signature   Done  84313412.0  File  tif  ...              False
# 9  Signature   Done  82452820.0  File  tif  ...              False
#
#                                          SHA256_HASH FORMAT_COUNT       PUID  \
# 0  8a0a01aa68bdf8e39604b747829f4c7fa38755ce335c3f...          1.0  x-fmt/387
# 1  256f682db10c7b57f5aaf4257bfa8220388383e8d835d2...          1.0  x-fmt/387
# 2  9320ca9074e19ad5537d1dc4b78d3574916c4d56bcc5f4...          1.0  x-fmt/387
# 3  a71db4bbd406b34f7e407240030a5eb82d72955ecc6e27...          1.0  x-fmt/387
# 4  9429574137662b13efa5256290a75982f9c3ec60245233...          1.0  x-fmt/387
# 5  d1f825df3279ef4bbaf61fa924013675d41b832381df73...          1.0  x-fmt/387
# 6  0ecbf845f0fb4048159a8bd5f398f45dec9c0a408d6652...          1.0  x-fmt/387
# 7  57bf87ae9aa9ae78527b9f11e76b96ea7fcb166fa1c27f...          1.0  x-fmt/387
# 8  2d2b5cb12ba35953b5bc7c8face86e961e5ae64eb47c4f...          1.0  x-fmt/387
# 9  2c21bc9212783746268ed5dd168a44163bdfebd8d47420...          1.0  x-fmt/387
#
#     MIME_TYPE                                    FORMAT_NAME FORMAT_VERSION  \
# 0  image/tiff  Exchangeable Image File Format (Uncompressed)            2.2
# 1  image/tiff  Exchangeable Image File Format (Uncompressed)            2.2
# 2  image/tiff  Exchangeable Image File Format (Uncompressed)            2.2
# 3  image/tiff  Exchangeable Image File Format (Uncompressed)            2.2
# 4  image/tiff  Exchangeable Image File Format (Uncompressed)            2.2
# 5  image/tiff  Exchangeable Image File Format (Uncompressed)            2.2
# 6  image/tiff  Exchangeable Image File Format (Uncompressed)            2.2
# 7  image/tiff  Exchangeable Image File Format (Uncompressed)            2.2
# 8  image/tiff  Exchangeable Image File Format (Uncompressed)            2.2
# 9  image/tiff  Exchangeable Image File Format (Uncompressed)            2.2
#
#                                           PARENT_DIR FolderCount  IsDuplicate
# 0  \\P12L-NAS5\Persian Digitisation\Grenville xli...           1         True
# 1  \\P12L-NAS5\Persian Digitisation\Grenville xli...           1         True
# 2  \\P12L-NAS5\Persian Digitisation\Grenville xli...           1         True
# 3  \\P12L-NAS5\Persian Digitisation\Grenville xli...           1         True
# 4  \\P12L-NAS5\Persian Digitisation\Grenville xli...           1         True
# 5  \\P12L-NAS5\Persian Digitisation\Grenville xli...           1         True
# 6  \\P12L-NAS5\Persian Digitisation\Grenville xli...           1         True
# 7  \\P12L-NAS5\Persian Digitisation\Grenville xli...           1         True
# 8  \\P12L-NAS5\Persian Digitisation\Grenville xli...           1         True
# 9  \\P12L-NAS5\Persian Digitisation\Grenville xli...           1         True
#
# [10 rows x 21 columns]

# %% [markdown]
# ### Combine IAMS metadata into master spreadsheet

# %% [markdown]
# This section uses the optional package [tqdm](https://github.com/tqdm/tqdm), which just adds a nice progress bar/timer to loops for free.
#
# First, import necessary modules and open the excel worksheets

# %%
import numpy as np
import pandas as pd 
from tqdm import tqdm
ms=pd.read_excel("AAC_CombinedAnalysis.xlsx",dtype=str) # set all dtypes to str
iam=pd.read_excel("AAC_IAMSReport.xlsx",dtype=str)

# %% [markdown]
# Replace any null values found with a blank string `""`

# %%
ms=ms.replace(np.nan,"")
iam=iam.replace(np.nan,"")

# %% [markdown]
# You could now loop over each row of both dataframes and perform string comparisons on the Shelfmark columns. However, even using the `iterrows` member function documented [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iterrows.html) makes this incredibly slow. I timed this on my laptop to come out somewhere around 40 minutes, and I managed to have it crash near the end twice in a row.
#
# Pandas DataFrames are essentially 2D arrays anyway and using [numpy arrays](https://docs.scipy.org/doc/numpy/reference/generated/numpy.array.html) for this string comparison works out much faster, getting the whole thing done in well under a minute. This does mean we lose the dataframe column headers though, so need to grab those first before converting things to 2D numpy arrays.

# %%
msCols=ms.columns.to_list()
iamCols=iam.columns.to_list()
iamColsMod=[]
for col in iamCols:
    iamColsMod.append("IAMS - "+col)

allCols=msCols+iamColsMod

# %% [markdown]
# Here I've prepended `IAMS - ` to each column heading from the IAMS report.
#
# Now convert both dataframes to 2D numpy arrays with dtype object*
#
# **If you convert to dtype=str this places a 10-character limit on each value by default, which is not what you want*

# %%
msn=ms.to_numpy(dtype=object)
iamn=iam.to_numpy(dtype=object)

# %% [markdown]
# We'd like an overall dataframe that includes values from both of the ones we already have, matched on the shelfmark. So make a blank 2D numpy array with the same number of rows as the master spreadsheet and the same number of columns as both spreadsheets combined. The `empty` function gives you an array of zeros in the shape you specify, all of `dtype=numpy.float64`. Since we've already defined the `msn` and `iamn` arrays as `dtype=object`, we don't want this. Also, to stop just inputting loads of zeros into the eventual spreadsheet, I convert all values to `NaN` before converting the entire array to `dtype=object`.

# %%
combined=np.empty([msn.shape[0],(iamn.shape[1]+msn.shape[1])])
combined[:]=np.nan
combined=combined.astype(object)

# %% [markdown]
# If there's no match from any row in the IAMS spreadsheet for a particular row in the master spreadsheet, we still want to input some blank cells for the IAMS report columns. So now construct a blank 2D array with the same shape as the IAMS report array, again of dtype=object.

# %%
blanks=np.empty(iamn.shape,dtype=object)

# %% [markdown]
# Now loop over both `msn` and `iamn` and find matches on the Shelfmark variable. I checked myself and for any row `n` this corresponds to `msn[n][0]` and `iamn[n][3]`, but this is something you can check yourself!
#
# This is roughly what the next block of code is doing, line-by-line:
#
# - Start with a for loop over `msn`
# - initialise `rowMatch` as `False`
# - Then start looping over `iamn`
# - An `if` statement to compare two strings.
#     - First take the value of shelfmark from `iamn`, remove any whitespace and use `.casefold()` to convert everything to lower-case.
#     - Then compare this to the shelfmark from `msn`, with the same whitespace and upper case removal
#     - This is just a case-independent string comparison!
# - If a Shelfmark match is found:
#     - Set `rowMatch=True`
#     - Change the row in the large 'combined' 2D array we made to equal all of the values from the current row in `msn` with all of the values from this particular `iamn` row stuck on the end
# - If, after checking all of the rows in `iamn`, no match is found:
#     - Change the row in the large 'combined' 2D array we made to equal all of the values from the current row in `msn` with blank values added to the end.
# - Once all the rows in `msn` have been checked, the `combined` 2D array is no longer blank!

# %%
for i in tqdm(range(0,len(msn))):
    rowMatch=False
    for j in range(0,len(iamn)):
        if iamn[j][3].replace(" ","").casefold() == msn[i][0].replace(" ","").casefold():
            rowMatch=True
            combined[i]=np.concatenate([msn[i],iamn[j]])
    if not rowMatch:
        combined[i]=np.concatenate([msn[i],blanks[0]])
# Out:
# 100%|██████████| 7646/7646 [00:27<00:00, 278.73it/s]

# %% [markdown]
# Now have this 2x2 numpy array... turn it into a pandas DataFrame using the column names we saved earlier

# %%
mergedDF=pd.DataFrame(combined,columns=allCols)
mergedDF
# Out:
#      Shelfmark Parent Label System number Volume enumeration  \
# 0            ?
# 1            ?
# 2            ?
# 3            ?
# 4            ?
# ...        ...    ...   ...           ...                ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#                Project (if part of a Project) DAR number  \
# 0     Hebrew Manuscripts Digitisation Project    DAR 354
# 1
# 2
# 3
# 4
# ...                                       ...        ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#                                           Source folder Output Folder  \
# 0     \\p12l-nas5\Hebrew MSS Digitisation\Hebrew MSS...
# 1     \\P12L-NAS5\Preservation Digitisation Bids 201...
# 2     \\P12L-NAS5\Preservation Digitisation Bids 201...
# 3     \\P12L-NAS5\Preservation Digitisation Bids 201...
# 4     \\P12L-NAS5\Preservation Digitisation Bids 201...
# ...                                                 ...           ...
# 7641  \\P8L-NAS2\AAS Storage\ZZZ - UNIDENTIFIED OR U...
# 7642  \\V12L-NAS4\SEAsia\BUGIS MSS 2018\Studio Image...
# 7643  \\V12L-NAS4\SEAsia\Finished Javanese Manuscrip...
# 7644  \\V12L-NAS4\SEAsia\Finished Javanese Manuscrip...
# 7645  \\V12L-NAS4\SEAsia\JAVANESE MSS FROM YOGYA 201...
#
#      Ingest Format JP2 Quality Descriptive Metadata Source  \
# 0
# 1
# 2
# 3
# 4
# ...            ...         ...                         ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      Sequence Arrangement Physical Type Logical Type RAQ ID Usage  \
# 0
# 1
# 2
# 3
# 4
# ...                   ...           ...          ...    ...   ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      Additional Information Digitised By Funded By Notes Submit (Y/N) Result  \
# 0
# 1
# 2
# 3
# 4
# ...                     ...          ...       ...   ...          ...    ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      Complete or partial file set To be included in DIPS?  \
# 0                       Uncertain
# 1                        Complete
# 2                        Complete
# 3                        Complete
# 4                        Complete
# ...                           ...                     ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      To be ingested into DLS? Catalogued in Aleph or IAMS Notes.1  \
# 0                                                IAMS-TEI
# 1
# 2
# 3
# 4
# ...                       ...                         ...     ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      Quality issues Postproduction needed     HMD analyst       Curator  \
# 0                                          Green, Jessica  Tahan, Ilana
# 1                                          Green, Jessica   Roy, Malini
# 2                                          Green, Jessica   Roy, Malini
# 3                                          Green, Jessica   Roy, Malini
# 4                                          Green, Jessica   Roy, Malini
# ...             ...                   ...             ...           ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#                      Collection area  \
# 0      Asian and African Collections
# 1     Asian and African Collections
# 2     Asian and African Collections
# 3     Asian and African Collections
# 4     Asian and African Collections
# ...                              ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#                                            Section Additional locations  \
# 0     Middle Eastern and Central Asian Collections
# 1                                     Visual Arts
# 2                                     Visual Arts
# 3                                     Visual Arts
# 4                                     Visual Arts
# ...                                            ...                  ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      Total file size Number of TIFF files IAMS - Repository  \
# 0
# 1
# 2
# 3
# 4
# ...              ...                  ...               ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Collection area IAMS - Project collection IAMS - Record reference  \
# 0
# 1
# 2
# 3
# 4
# ...                     ...                       ...                     ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Record ID (unique internal identifier)  \
# 0
# 1
# 2
# 3
# 4
# ...                                            ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Metadata persistent identifier  \
# 0
# 1
# 2
# 3
# 4
# ...                                    ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Content persistent identifier  \
# 0
# 1
# 2
# 3
# 4
# ...                                   ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Interim content persistent identifier IAMS - Digital object URL  \
# 0
# 1
# 2
# 3
# 4
# ...                                           ...                       ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Former internal reference IAMS - Former external reference  \
# 0
# 1
# 2
# 3
# 4
# ...                               ...                              ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Type of record (level) IAMS - Record format IAMS - Parent  \
# 0
# 1
# 2
# 3
# 4
# ...                            ...                  ...           ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Sibling order IAMS - Title IAMS - Date range IAMS - Start date  \
# 0
# 1
# 2
# 3
# 4
# ...                   ...          ...               ...               ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - End date IAMS - Calendar IAMS - Era IAMS - Creators  \
# 0
# 1
# 2
# 3
# 4
# ...              ...             ...        ...             ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Extent & format IAMS - Access conditions IAMS - Access date  \
# 0
# 1
# 2
# 3
# 4
# ...                     ...                      ...                ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - User conditions IAMS - Languages IAMS - Language codes  \
# 0
# 1
# 2
# 3
# 4
# ...                     ...              ...                   ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Scripts IAMS - Script codes IAMS - Scope & content IAMS - Scale  \
# 0
# 1
# 2
# 3
# 4
# ...             ...                 ...                    ...          ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Scale designator IAMS - Projection IAMS - Decimal coordinates  \
# 0
# 1
# 2
# 3
# 4
# ...                      ...               ...                        ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Degree coordinates IAMS - Decimal latitude  \
# 0
# 1
# 2
# 3
# 4
# ...                        ...                     ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Decimal longitude IAMS - Degree latitude IAMS - Degree longitude  \
# 0
# 1
# 2
# 3
# 4
# ...                       ...                    ...                     ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Orientation IAMS - Material type IAMS - Style IAMS - Technique  \
# 0
# 1
# 2
# 3
# 4
# ...                 ...                  ...          ...              ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Physical characteristics IAMS - Appraisal IAMS - Accruals  \
# 0
# 1
# 2
# 3
# 4
# ...                              ...              ...             ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Arrangement IAMS - Immediate source of acquisition  \
# 0
# 1
# 2
# 3
# 4
# ...                 ...                                    ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Custodial history IAMS - Administrative context  \
# 0
# 1
# 2
# 3
# 4
# ...                       ...                           ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Related material IAMS - Related archive descriptions  \
# 0
# 1
# 2
# 3
# 4
# ...                      ...                                 ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Related names IAMS - Related places IAMS - Related subjects  \
# 0
# 1
# 2
# 3
# 4
# ...                   ...                   ...                     ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Copies information IAMS - Originals information  \
# 0
# 1
# 2
# 3
# 4
# ...                        ...                          ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Finding aids IAMS - Publication note IAMS - Exhibition  \
# 0
# 1
# 2
# 3
# 4
# ...                  ...                     ...               ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Notes IAMS - Status IAMS - Visibility IAMS - Level of detail  \
# 0
# 1
# 2
# 3
# 4
# ...           ...           ...               ...                    ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Legal status IAMS - Description language  \
# 0
# 1
# 2
# 3
# 4
# ...                  ...                         ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Description language code IAMS - Description script  \
# 0
# 1
# 2
# 3
# 4
# ...                               ...                       ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Description script code IAMS - Logical type IAMS - Logical label  \
# 0
# 1
# 2
# 3
# 4
# ...                             ...                 ...                  ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Page sequence range IAMS - Page label range  \
# 0
# 1
# 2
# 3
# 4
# ...                         ...                     ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Bibliographical reference rules  \
# 0
# 1
# 2
# 3
# 4
# ...                                     ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Institution identifier rules IAMS - Countries rules  \
# 0
# 1
# 2
# 3
# 4
# ...                                  ...                    ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Structure rules IAMS - Dates rules IAMS - Name rules  \
# 0
# 1
# 2
# 3
# 4
# ...                     ...                ...               ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Description rules IAMS - Relationship categories rules  \
# 0
# 1
# 2
# 3
# 4
# ...                       ...                                  ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Relationship descriptions rules IAMS - Language rules  \
# 0
# 1
# 2
# 3
# 4
# ...                                     ...                   ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Script rules IAMS - Repository.1 IAMS - Collection area.1  \
# 0
# 1
# 2
# 3
# 4
# ...                  ...                 ...                      ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Project collection.1 IAMS - Record reference.1  \
# 0
# 1
# 2
# 3
# 4
# ...                          ...                       ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Record ID (unique internal identifier).1  \
# 0
# 1
# 2
# 3
# 4
# ...                                              ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Metadata persistent identifier.1  \
# 0
# 1
# 2
# 3
# 4
# ...                                      ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Content persistent identifier.1  \
# 0
# 1
# 2
# 3
# 4
# ...                                     ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Interim content persistent identifier.1  \
# 0
# 1
# 2
# 3
# 4
# ...                                             ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Digital object URL.1 IAMS - Former internal reference.1  \
# 0
# 1
# 2
# 3
# 4
# ...                          ...                                ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Former external reference.1 IAMS - Type of record (level).1  \
# 0
# 1
# 2
# 3
# 4
# ...                                 ...                             ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Record format.1 IAMS - Parent.1 IAMS - Sibling order.1  \
# 0
# 1
# 2
# 3
# 4
# ...                     ...             ...                    ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Title.1 IAMS - Date range.1 IAMS - Start date.1 IAMS - End date.1  \
# 0
# 1
# 2
# 3
# 4
# ...             ...                 ...                 ...               ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Calendar.1 IAMS - Era.1 IAMS - Creators.1  \
# 0
# 1
# 2
# 3
# 4
# ...                ...          ...               ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Extent & format.1 IAMS - Access conditions.1 IAMS - Access date.1  \
# 0
# 1
# 2
# 3
# 4
# ...                       ...                        ...                  ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - User conditions.1 IAMS - Languages.1 IAMS - Language codes.1  \
# 0
# 1
# 2
# 3
# 4
# ...                       ...                ...                     ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Scripts.1 IAMS - Script codes.1 IAMS - Scope & content.1  \
# 0
# 1
# 2
# 3
# 4
# ...               ...                   ...                      ...
# 7641
# 7642
# 7643
# 7644
# 7645
#
#      IAMS - Scale.1 IAMS - Scale designator.1 IAMS - Projection.1  \
# 0
# 1
# 2
# 3
# ...
# 7645                      None                    None
#
#      IAMS - Decimal longitude IAMS - Degree latitude IAMS - Degree longitude  \
# 0                        None                   None                    None
# 1                        None                   None                    None
# 2                        None                   None                    None
# 3                        None                   None                    None
# 4                        None                   None                    None
# ...                       ...                    ...                     ...
# 7641                     None                   None                    None
# 7642                     None                   None                    None
# 7643                     None                   None                    None
# 7644                     None                   None                    None
# 7645                     None                   None                    None
#
#      IAMS - Orientation IAMS - Material type IAMS - Style IAMS - Technique  \
# 0                  None                 None         None             None
# 1                  None                 None         None             None
# 2                  None                 None         None             None
# 3                  None                 None         None             None
# 4                  None                 None         None             None
# ...                 ...                  ...          ...              ...
# 7641               None                 None         None             None
# 7642               None                 None         None             None
# 7643               None                 None         None             None
# 7644               None                 None         None             None
# 7645               None                 None         None             None
#
#      IAMS - Physical characteristics IAMS - Appraisal IAMS - Accruals  \
# 0                               None             None            None
# 1                               None             None            None
# 2                               None             None            None
# 3                               None             None            None
# 4                               None             None            None
# ...                              ...              ...             ...
# 7641                            None             None            None
# 7642                            None             None            None
# 7643                            None             None            None
# 7644                            None             None            None
# 7645                            None             None            None
#
#      IAMS - Arrangement IAMS - Immediate source of acquisition  \
# 0                  None                                   None
# 1                  None                                   None
# 2                  None                                   None
# 3                  None                                   None
# 4                  None                                   None
# ...                 ...                                    ...
# 7641               None                                   None
# 7642               None                                   None
# 7643               None                                   None
# 7644               None                                   None
# 7645               None                                   None
#
#      IAMS - Custodial history IAMS - Administrative context  \
# 0                        None                          None
# 1                        None                          None
# 2                        None                          None
# 3                        None                          None
# 4                        None                          None
# ...                       ...                           ...
# 7641                     None                          None
# 7642                     None                          None
# 7643                     None                          None
# 7644                     None                          None
# 7645                     None                          None
#
#      IAMS - Related material IAMS - Related archive descriptions  \
# 0                       None                                None
# 1                       None                                None
# 2                       None                                None
# 3                       None                                None
# 4                       None                                None
# ...                      ...                                 ...
# 7641                    None                                None
# 7642                    None                                None
# 7643                    None                                None
# 7644                    None                                None
# 7645                    None                                None
#
#      IAMS - Related names IAMS - Related places IAMS - Related subjects  \
# 0                    None                  None                    None
# 1                    None                  None                    None
# 2                    None                  None                    None
# 3                    None                  None                    None
# 4                    None                  None                    None
# ...                   ...                   ...                     ...
# 7641                 None                  None                    None
# 7642                 None                  None                    None
# 7643                 None                  None                    None
# 7644                 None                  None                    None
# 7645                 None                  None                    None
#
#      IAMS - Copies information IAMS - Originals information  \
# 0                         None                         None
# 1                         None                         None
# 2                         None                         None
# 3                         None                         None
# 4                         None                         None
# ...                        ...                          ...
# 7641                      None                         None
# 7642                      None                         None
# 7643                      None                         None
# 7644                      None                         None
# 7645                      None                         None
#
#      IAMS - Finding aids IAMS - Publication note IAMS - Exhibition  \
# 0                   None                    None              None
# 1                   None                    None              None
# 2                   None                    None              None
# 3                   None                    None              None
# 4                   None                    None              None
# ...                  ...                     ...               ...
# 7641                None                    None              None
# 7642                None                    None              None
# 7643                None                    None              None
# 7644                None                    None              None
# 7645                None                    None              None
#
#      IAMS - Notes IAMS - Status IAMS - Visibility IAMS - Level of detail  \
# 0            None          None              None                   None
# 1            None          None              None                   None
# 2            None          None              None                   None
# 3            None          None              None                   None
# 4            None          None              None                   None
# ...           ...           ...               ...                    ...
# 7641         None          None              None                   None
# 7642         None          None              None                   None
# 7643         None          None              None                   None
# 7644         None          None              None                   None
# 7645         None          None              None                   None
#
#      IAMS - Legal status IAMS - Description language  \
# 0                   None                        None
# 1                   None                        None
# 2                   None                        None
# 3                   None                        None
# 4                   None                        None
# ...                  ...                         ...
# 7641                None                        None
# 7642                None                        None
# 7643                None                        None
# 7644                None                        None
# 7645                None                        None
#
#      IAMS - Description language code IAMS - Description script  \
# 0                                None                      None
# 1                                None                      None
# 2                                None                      None
# 3                                None                      None
# 4                                None                      None
# ...                               ...                       ...
# 7641                             None                      None
# 7642                             None                      None
# 7643                             None                      None
# 7644                             None                      None
# 7645                             None                      None
#
#      IAMS - Description script code IAMS - Logical type IAMS - Logical label  \
# 0                              None                None                 None
# 1                              None                None                 None
# 2                              None                None                 None
# 3                              None                None                 None
# 4                              None                None                 None
# ...                             ...                 ...                  ...
# 7641                           None                None                 None
# 7642                           None                None                 None
# 7643                           None                None                 None
# 7644                           None                None                 None
# 7645                           None                None                 None
#
#      IAMS - Page sequence range IAMS - Page label range  \
# 0                          None                    None
# 1                          None                    None
# 2                          None                    None
# 3                          None                    None
# 4                          None                    None
# ...                         ...                     ...
# 7641                       None                    None
# 7642                       None                    None
# 7643                       None                    None
# 7644                       None                    None
# 7645                       None                    None
#
#      IAMS - Bibliographical reference rules  \
# 0                                      None
# 1                                      None
# 2                                      None
# 3                                      None
# 4                                      None
# ...                                     ...
# 7641                                   None
# 7642                                   None
# 7643                                   None
# 7644                                   None
# 7645                                   None
#
#      IAMS - Institution identifier rules IAMS - Countries rules  \
# 0                                   None                   None
# 1                                   None                   None
# 2                                   None                   None
# 3                                   None                   None
# 4                                   None                   None
# ...                                  ...                    ...
# 7641                                None                   None
# 7642                                None                   None
# 7643                                None                   None
# 7644                                None                   None
# 7645                                None                   None
#
#      IAMS - Structure rules IAMS - Dates rules IAMS - Name rules  \
# 0                      None               None              None
# 1                      None               None              None
# 2                      None               None              None
# 3                      None               None              None
# 4                      None               None              None
# ...                     ...                ...               ...
# 7641                   None               None              None
# 7642                   None               None              None
# 7643                   None               None              None
# 7644                   None               None              None
# 7645                   None               None              None
#
#      IAMS - Description rules IAMS - Relationship categories rules  \
# 0                        None                                 None
# 1                        None                                 None
# 2                        None                                 None
# 3                        None                                 None
# 4                        None                                 None
# ...                       ...                                  ...
# 7641                     None                                 None
# 7642                     None                                 None
# 7643                     None                                 None
# 7644                     None                                 None
# 7645                     None                                 None
#
#      IAMS - Relationship descriptions rules IAMS - Language rules  \
# 0                                      None                  None
# 1                                      None                  None
# 2                                      None                  None
# 3                                      None                  None
# 4                                      None                  None
# ...                                     ...                   ...
# 7641                                   None                  None
# 7642                                   None                  None
# 7643                                   None                  None
# 7644                                   None                  None
# 7645                                   None                  None
#
#      IAMS - Script rules
# 0                   None
# 1                   None
# 2                   None
# 3                   None
# 4                   None
# ...                  ...
# 7641                None
# 7642                None
# 7643                None
# 7644                None
# 7645                None
#
# [7646 rows x 292 columns]

# %% [markdown]
# Then, optionally, write this to a file:

# %%
mergedDF.to_excel("AAC_CombinedAnalysis_MergedIAMS_jN.xlsx",index=False)

# %% [markdown]
# N.B. this will produce an excel file with absolutely no formatting, which is probably not wanted. For now I've just used this as a way to make an excel file with the exact same rows as the original AAC_CombinedAnalysis spreadsheet so that the extra IAMS information can be copy-pasted directly into the original spreadsheet, which retains the formatting.

# %% [markdown]
# ### To-do in this section:
# Task - Priority
# - Adjust absolute folder paths for those that were migrated to new servers - medium
# - Combine Aleph metadata into Master Spreadsheet (after Jess confirms shelfmarks/system numbers) - low
# - Combine Customer Order information into Master Spreadsheet - low
# - Concatenate the two Notes columns, separated by ; - low
#
#
# - Combine Siegfried output into master spreadsheet - are we still trying this, or keeping Siegfried separate?

# %% [markdown]
# ## Corruption & data loss

# %% [markdown]
# ### To-do:
# Task - priority
# - In the folders containing exact duplicates, which of these folders also contain not-exact duplicates? - medium
# - In the folders containing exact duplicates, which of these folders have a mismatch re number of files? - medium
# - In the folders containing sets of images, are any files significantly smaller than the others? (threshold?) - medium
# - In the folders containing duplicate sets of images, do any of the folders contain a different number of TIFF files? - medium

# %% [markdown]
# ### Which files have file size of 0 MB?

# %% [markdown]
# Only three files have a size less than 1 KB, and none have a size of 0 MB.

# %%
allData[allData.SIZE<1000] # size in bytes
# Out:
#             ID PARENT_ID                                                URI  \
# 595161  646078            file:///P8L-NAS2/AAS%20Storage/ZZZ%20-%20UNIDE...
# 595223  646140            file:///P8L-NAS2/AAS%20Storage/ZZZ%20-%20UNIDE...
# 595312  646229            file:///P8L-NAS2/AAS%20Storage/ZZZ%20-%20UNIDE...
#
#                                                 FILE_PATH       NAME  \
# 595161  \\P8L-NAS2\AAS Storage\ZZZ - UNIDENTIFIED OR U...  00004.tif
# 595223  \\P8L-NAS2\AAS Storage\ZZZ - UNIDENTIFIED OR U...  00066.tif
# 595312  \\P8L-NAS2\AAS Storage\ZZZ - UNIDENTIFIED OR U...  00155.tif
#
#            METHOD STATUS   SIZE  TYPE  EXT         LAST_MODIFIED  \
# 595161  Signature   Done  668.0  File  tif  2016-03-09T11:49:29Z
# 595223  Signature   Done  626.0  File  tif  2016-03-09T11:51:39Z
# 595312  Signature   Done  642.0  File  tif  2016-03-09T11:52:43Z
#
#         EXTENSION_MISMATCH                                        SHA256_HASH  \
# 595161               False  3ec734de8906f949d2092c76a1da28cc9c84ed221049a4...
# 595223               False  437f28c852b1e1d1b6937b87014767f0b5398c5c4e44ec...
# 595312               False  14345af01ba3eeeae71eeb6e6b45d9cbd96dba8124614c...
#
#         FORMAT_COUNT     PUID   MIME_TYPE               FORMAT_NAME  \
# 595161           1.0  fmt/353  image/tiff  Tagged Image File Format
# 595223           1.0  fmt/353  image/tiff  Tagged Image File Format
# 595312           1.0  fmt/353  image/tiff  Tagged Image File Format
#
#        FORMAT_VERSION                                         PARENT_DIR  \
# 595161                 \\P8L-NAS2\AAS Storage\ZZZ - UNIDENTIFIED OR U...
# 595223                 \\P8L-NAS2\AAS Storage\ZZZ - UNIDENTIFIED OR U...
# 595312                 \\P8L-NAS2\AAS Storage\ZZZ - UNIDENTIFIED OR U...
#
#         FolderCount
# 595161            1
# 595223            1
# 595312            1

# %% [markdown]
# ### Which files have a file mismatch? File extension = true

# %% [markdown]
# Only one file identified as tif by MIME_TYPE is affected

# %%
allData[allData['EXTENSION_MISMATCH']]
# Out:
#             ID PARENT_ID                                                URI  \
# 740608  791881            file:///P8L-NAS2/Singapore-Malay/Finished%20Ma...
#
#                                                 FILE_PATH         NAME  \
# 740608  \\P8L-NAS2\Singapore-Malay\Finished Manuscript...  ~psB4B4.tmp
#
#            METHOD STATUS         SIZE  TYPE  EXT         LAST_MODIFIED  \
# 740608  Signature   Done  102065984.0  File  tmp  2015-03-12T17:23:02Z
#
#         EXTENSION_MISMATCH                                        SHA256_HASH  \
# 740608                True  ff602f7eeb24442c251f7f573e9465a9f8bb7277b2f577...
#
#         FORMAT_COUNT       PUID   MIME_TYPE  \
# 740608           1.0  x-fmt/387  image/tiff
#
#                                           FORMAT_NAME FORMAT_VERSION  \
# 740608  Exchangeable Image File Format (Uncompressed)            2.2
#
#                                                PARENT_DIR  FolderCount
# 740608  \\P8L-NAS2\Singapore-Malay\Finished Manuscript...            1

# %% [markdown]
# Using the entire Siegfried output, find all duplicates (including the original) with the same method used above. After this, group the output by parent folder with `groupby`. This produces one row per parent folder, so all other columns have some operation applied to them. In this case they are aggregated - simply summed if the data type is `float64` or concatenated into a single string in any other case. For `SHA256_HASH`, this will produce a single hash from all items in a folder. If two parent directories have the same combined hash, they are full duplicates of each other, if not there is some difference with one or more files within a folder.

# %%
dao=allData[allData.duplicated(subset="SHA256_HASH",keep=False)]
DupFolders=dao.groupby(['PARENT_DIR'],as_index=False).agg(lambda x : x.sum() if x.dtype=='float64' else ' '.join(x))
DupFolders
# Out:
#                                              PARENT_DIR  \
# 0     \\P12L-NAS5\Persian Digitisation\Grenville xli...
# 1     \\P12L-NAS5\Persian Digitisation\IO Islamic 10...
# 2     \\P12L-NAS5\Persian Digitisation\IO Islamic 12...
# 3     \\P12L-NAS5\Persian Digitisation\IO Islamic 13...
# 4     \\P12L-NAS5\Persian Digitisation\IO Islamic 13...
# ...                                                 ...
# 1286  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1287  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1288  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1289  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1290  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
#
#                                               PARENT_ID  \
# 0                                                   ...
# 1                                                   ...
# 2                                                   ...
# 3                                                   ...
# 4                                                   ...
# ...                                                 ...
# 1286                                                ...
# 1287
# 1288
# 1289
# 1290                                                ...
#
#                                                     URI  \
# 0     file:///P12L-NAS5/Persian%20Digitisation/Grenv...
# 1     file:///P12L-NAS5/Persian%20Digitisation/IO%20...
# 2     file:///P12L-NAS5/Persian%20Digitisation/IO%20...
# 3     file:///P12L-NAS5/Persian%20Digitisation/IO%20...
# 4     file:///P12L-NAS5/Persian%20Digitisation/IO%20...
# ...                                                 ...
# 1286  file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
# 1287  file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
# 1288  file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
# 1289  file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
# 1290  file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
#
#                                               FILE_PATH  \
# 0     \\P12L-NAS5\Persian Digitisation\Grenville xli...
# 1     \\P12L-NAS5\Persian Digitisation\IO Islamic 10...
# 2     \\P12L-NAS5\Persian Digitisation\IO Islamic 12...
# 3     \\P12L-NAS5\Persian Digitisation\IO Islamic 13...
# 4     \\P12L-NAS5\Persian Digitisation\IO Islamic 13...
# ...                                                 ...
# 1286  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1287  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1288  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1289  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 1290  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
#
#                                                    NAME  \
# 0     grenville_xli_f001r.tif grenville_xli_f001v.ti...
# 1     io_islamic_1026_f001r.tif io_islamic_1026_f001...
# 2     i_o_islamic_1256_control1.tif i_o_islamic_1256...
# 3     io_islamic_132_f001r.tif io_islamic_132_f001v....
# 4     io_islamic_137_f001r.tif io_islamic_137_f001v....
# ...                                                 ...
# 1286  or_16790_f001r.tif or_16790_f001v.tif or_16790...
# 1287  or_16893_f001r.tif or_16893_f001v.tif or_16893...
# 1288  OR_4736_f001r.tif OR_4736_f001v.tif OR_4736_f0...
# 1289  or_4762_f001r.tif or_4762_f003r.tif or_4762_f0...
# 1290  or_7458_f001r.tif or_7458_f001v.tif or_7458_f0...
#
#                                                  METHOD  \
# 0     Signature Signature Signature Signature Signat...
# 1     Signature Signature Signature Signature Signat...
# 2     Signature Signature Signature Signature Signat...
# 3     Signature Signature Signature Signature Signat...
# 4     Signature Signature Signature Signature Signat...
# ...                                                 ...
# 1286  Signature Signature Signature Signature Signat...
# 1287  Signature Signature Signature Signature Signat...
# 1288  Signature Signature Signature Signature Signat...
# 1289  Signature Signature Signature Signature Signat...
# 1290  Signature Signature Signature Signature Signat...
#
#                                                  STATUS          SIZE  \
# 0     Done Done Done Done Done Done Done Done Done D...  4.396242e+10
# 1     Done Done Done Done Done Done Done Done Done D...  3.393058e+10
# 2     Done Done Done Done Done Done Done Done Done D...  1.283186e+11
# 3     Done Done Done Done Done Done Done Done Done D...  2.354463e+10
# 4     Done Done Done Done Done Done Done Done Done D...  1.518890e+11
# ...                                                 ...           ...
# 1286  Done Done Done Done Done Done Done Done Done D...  3.218073e+09
# 1287  Done Done Done Done Done Done Done Done Done D...  2.251035e+09
# 1288  Done Done Done Done Done Done Done Done Done D...  3.667863e+09
# 1289  Done Done Done Done Done Done Done Done Done Done  7.914676e+08
# 1290  Done Done Done Done Done Done Done Done Done D...  1.285657e+10
#
#                                                    TYPE  \
# 0     File File File File File File File File File F...
# 1     File File File File File File File File File F...
# 2     File File File File File File File File File F...
# 3     File File File File File File File File File F...
# 4     File File File File File File File File File F...
# ...                                                 ...
# 1286  File File File File File File File File File F...
# 1287  File File File File File File File File File F...
# 1288  File File File File File File File File File F...
# 1289  File File File File File File File File File File
# 1290  File File File File File File File File File F...
#
#                                                     EXT  \
# 0     tif tif tif tif tif tif tif tif tif tif tif ti...
# 1     tif tif tif tif tif tif tif tif tif tif tif ti...
# 2     tif tif tif tif tif tif tif tif tif tif tif ti...
# 3     tif tif tif tif tif tif tif tif tif tif tif ti...
# 4     tif tif tif tif tif tif tif tif tif tif tif ti...
# ...                                                 ...
# 1286  tif tif tif tif tif tif tif tif tif tif tif ti...
# 1287  tif tif tif tif tif tif tif tif tif tif tif ti...
# 1288  tif tif tif tif tif tif tif tif tif tif tif ti...
# 1289            tif tif tif tif tif tif tif tif tif tif
# 1290  tif tif tif tif tif tif tif tif tif tif tif ti...
#
#                                           LAST_MODIFIED  \
# 0     2013-04-22T10:40:14+01:00 2013-04-25T10:57:52+...
# 1     2013-07-01T13:54:14+01:00 2013-07-01T13:54:29+...
# 2     2017-03-29T15:08:45+01:00 2017-03-29T18:12:14+...
# 3     2012-04-17T14:46:46+01:00 2012-04-17T14:46:48+...
# 4     2013-06-07T18:52:07+01:00 2013-06-13T14:37:29+...
# ...                                                 ...
# 1286  2016-02-10T14:46:16Z 2016-02-10T14:46:21Z 2016...
# 1287  2016-02-12T12:50:29Z 2016-02-12T12:50:34Z 2016...
# 1288  2010-09-30T13:49:26+01:00 2010-09-30T13:49:40+...
# 1289  2014-06-11T09:44:48+01:00 2014-06-11T09:44:55+...
# 1290  2007-01-03T18:08:46Z 2007-01-03T18:10:42Z 2007...
#
#                                             SHA256_HASH  FORMAT_COUNT  \
# 0     8a0a01aa68bdf8e39604b747829f4c7fa38755ce335c3f...         525.0
# 1     7f6cfc2493d57883879a7748b60642860cbf685ec2adcc...         209.0
# 2     bf6c13f089a0e3c4cd1f1c1d5ed22d16f008ae8cc05d75...        1267.0
# 3     eab0f473c4ad2cd46b3c693962cae540a06d11174d023a...         224.0
# 4     27f7e2ff0cd5174600aa9c81aea7148d0749dce6067656...         975.0
# ...                                                 ...           ...
# 1286  2b21daa51ab5f7e6fa8c318e3cd6d8d437d7baa3d57815...          51.0
# 1287  6d0ee35ff048185b17811188c79407930ebc0d963968b3...          36.0
# 1288  c6ac5b14aad32010d0474c226223f7ea12433de686ce3e...          40.0
# 1289  bb88163b8add9cafc2b6e8ff7b3b4fdb594899661afa99...          10.0
# 1290  f4dd19b351f1e9ae596d131af1020f87709c07e19edb22...         194.0
#
#                                                    PUID  \
# 0     x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/...
# 1     x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/...
# 2     fmt/353 fmt/353 fmt/353 fmt/353 fmt/353 fmt/35...
# 3     x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/...
# 4     x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/...
# ...                                                 ...
# 1286  x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/...
# 1287  x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/...
# 1288  x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/...
# 1289  x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/...
# 1290  x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/...
#
#                                               MIME_TYPE  \
# 0     image/tiff image/tiff image/tiff image/tiff im...
# 1     image/tiff image/tiff image/tiff image/tiff im...
# 2     image/tiff image/tiff image/tiff image/tiff im...
# 3     image/tiff image/tiff image/tiff image/tiff im...
# 4     image/tiff image/tiff image/tiff image/tiff im...
# ...                                                 ...
# 1286  image/tiff image/tiff image/tiff image/tiff im...
# 1287  image/tiff image/tiff image/tiff image/tiff im...
# 1288  image/tiff image/tiff image/tiff image/tiff im...
# 1289  image/tiff image/tiff image/tiff image/tiff im...
# 1290  image/tiff image/tiff image/tiff image/tiff im...
#
#                                             FORMAT_NAME
# 0     Exchangeable Image File Format (Uncompressed) ...
# 1     Exchangeable Image File Format (Uncompressed) ...
# 2     Tagged Image File Format Tagged Image File For...
# 3     Exchangeable Image File Format (Uncompressed) ...
# 4     Exchangeable Image File Format (Uncompressed) ...
# ...                                                 ...
# 1286  Exchangeable Image File Format (Uncompressed) ...
# 1287  Exchangeable Image File Format (Uncompressed) ...
# 1288  Exchangeable Image File Format (Uncompressed) ...
# 1289  Exchangeable Image File Format (Uncompressed) ...
# 1290  Exchangeable Image File Format (Uncompressed) ...
#
# [1291 rows x 16 columns]

# %%
DupFolders[DupFolders.duplicated(subset="SHA256_HASH",keep=False)].sort_values(by='SHA256_HASH')
# Out:
#                                              PARENT_DIR  \
# 1043  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Persian...
# 496   \\P8L-NAS2\AAS Storage\Syriac (IT)\add_ms_1465...
# 1261  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 406   \\P8L-NAS2\AAS Storage\Southeast Asia (ATG)\Th...
# 97    \\P8L-NAS2\AAS Storage\AAS Legacy Images\io_sa...
# ...                                                 ...
# 1169  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 647   \\P8L-NAS3\Legacy Digital Content\Portfolio - ...
# 590   \\P8L-NAS2\AAS Storage\ZZZ - UNIDENTIFIED OR U...
# 58     \\P12L-NAS5\Persian Digitisation\or 4615\or_4615
# 1118  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Persian...
#
#                                               PARENT_ID  \
# 1043                                                ...
# 496                                                 ...
# 1261
# 406
# 97                                                  ...
# ...                                                 ...
# 1169
# 647                                                 ...
# 590                                                 ...
# 58                                                  ...
# 1118                                                ...
#
#                                                     URI  \
# 1043  file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
# 496   file:///P8L-NAS2/AAS%20Storage/Syriac%20%28IT%...
# 1261  file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
# 406   file:///P8L-NAS2/AAS%20Storage/Southeast%20Asi...
# 97    file:///P8L-NAS2/AAS%20Storage/AAS%20Legacy%20...
# ...                                                 ...
# 1169  file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
# 647   file:///P8L-NAS3/Legacy%20Digital%20Content/Po...
# 590   file:///P8L-NAS2/AAS%20Storage/ZZZ%20-%20UNIDE...
# 58    file:///P12L-NAS5/Persian%20Digitisation/or%20...
# 1118  file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
#
#                                               FILE_PATH  \
# 1043  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Persian...
# 496   \\P8L-NAS2\AAS Storage\Syriac (IT)\add_ms_1465...
# 1261  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 406   \\P8L-NAS2\AAS Storage\Southeast Asia (ATG)\Th...
# 97    \\P8L-NAS2\AAS Storage\AAS Legacy Images\io_sa...
# ...                                                 ...
# 1169  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
# 647   \\P8L-NAS3\Legacy Digital Content\Portfolio - ...
# 590   \\P8L-NAS2\AAS Storage\ZZZ - UNIDENTIFIED OR U...
# 58    \\P12L-NAS5\Persian Digitisation\or 4615\or_46...
# 1118  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Persian...
#
#                                                    NAME  \
# 1043  add_ms_14654_f001r.tif add_ms_14654_f001v.tif ...
# 496   add_ms_14654_f001r.tif add_ms_14654_f001v.tif ...
# 1261  or.15749!16.2_f001r.tif or.15749!16.2_f001v.ti...
# 406   or.15749!16.2_f001r.tif or.15749!16.2_f001v.ti...
# 97    io_san_3177_f001r.tif io_san_3177_f001v.tif io...
# ...                                                 ...
# 1169  or.15749!12.13_f001r.tif or.15749!12.13_f001v....
# 647   003909.tif 011792.tif 011793.TIF 011796.tif 01...
# 590   003909.tif 011792.tif 011793.TIF 011796.tif 01...
# 58    or_4615_f001r.tif or_4615_f001v.tif or_4615_f0...
# 1118  or_4615_f001r.tif or_4615_f001v.tif or_4615_f0...
#
#                                                  METHOD  \
# 1043  Signature Signature Signature Signature Signat...
# 496   Signature Signature Signature Signature Signat...
# 1261                      Signature Signature Signature
# 406                       Signature Signature Signature
# 97    Signature Signature Signature Signature Signat...
# ...                                                 ...
# 1169  Signature Signature Signature Signature Signat...
# 647   Signature Signature Signature Signature Signat...
# 590   Signature Signature Signature Signature Signat...
# 58    Signature Signature Signature Signature Signat...
# 1118  Signature Signature Signature Signature Signat...
#
#                                                  STATUS          SIZE  \
# 1043  Done Done Done Done Done Done Done Done Done D...  1.270663e+10
# 496   Done Done Done Done Done Done Done Done Done D...  1.270663e+10
# 1261                                     Done Done Done  2.769810e+08
# 406                                      Done Done Done  2.769810e+08
# 97    Done Done Done Done Done Done Done Done Done D...  2.286524e+10
# ...                                                 ...           ...
# 1169                 Done Done Done Done Done Done Done  6.578822e+08
# 647   Done Done Done Done Done Done Done Done Done D...  4.789564e+09
# 590   Done Done Done Done Done Done Done Done Done D...  4.789564e+09
# 58    Done Done Done Done Done Done Done Done Done D...  4.548648e+10
# 1118  Done Done Done Done Done Done Done Done Done D...  4.548648e+10
#
#                                                    TYPE  \
# 1043  File File File File File File File File File F...
# 496   File File File File File File File File File F...
# 1261                                     File File File
# 406                                      File File File
# 97    File File File File File File File File File F...
# ...                                                 ...
# 1169                 File File File File File File File
# 647   File File File File File File File File File F...
# 590   File File File File File File File File File F...
# 58    File File File File File File File File File F...
# 1118  File File File File File File File File File F...
#
#                                                     EXT  \
# 1043  tif tif tif tif tif tif tif tif tif tif tif ti...
# 496   tif tif tif tif tif tif tif tif tif tif tif ti...
# 1261                                        tif tif tif
# 406                                         tif tif tif
# 97    tif tif tif tif tif tif tif tif tif tif tif ti...
# ...                                                 ...
# 1169                        tif tif tif tif tif tif tif
# 647   tif tif TIF tif tif tif tif tif TIF tif tif ti...
# 590   tif tif TIF tif tif tif tif tif TIF tif tif ti...
# 58    tif tif tif tif tif tif tif tif tif tif tif ti...
# 1118  tif tif tif tif tif tif tif tif tif tif tif ti...
#
#                                           LAST_MODIFIED  \
# 1043  2013-03-28T13:28:34Z 2013-03-28T13:39:02Z 2013...
# 496   2013-03-28T13:28:34Z 2013-03-28T13:39:02Z 2013...
# 1261  2010-04-27T17:53:36+01:00 2010-04-27T17:53:48+...
# 406   2010-04-27T17:53:36+01:00 2010-04-27T17:53:48+...
# 97    2010-03-31T15:53:56+01:00 2010-03-31T15:53:50+...
# ...                                                 ...
# 1169  2010-04-15T15:29:53+01:00 2010-04-15T15:30:05+...
# 647   2009-08-20T17:32:18+01:00 2009-08-21T09:08:50+...
# 590   2009-08-20T17:32:18+01:00 2009-08-21T09:08:50+...
# 58    2013-05-22T11:57:15+01:00 2013-05-22T11:56:57+...
# 1118  2013-05-22T11:57:15+01:00 2013-05-22T11:56:57+...
#
#                                             SHA256_HASH  FORMAT_COUNT  \
# 1043  002615ad80eaf0f2d829580fe39daa2d2e42cc18d853bc...         145.0
# 496   002615ad80eaf0f2d829580fe39daa2d2e42cc18d853bc...         145.0
# 1261  006448265503f306c8f377c3c1a0eb5611ac4534796cd0...           3.0
# 406   006448265503f306c8f377c3c1a0eb5611ac4534796cd0...           3.0
# 97    008ccc4aa90709c33c50349f5a18808b16857ab2a2133a...         308.0
# ...                                                 ...           ...
# 1169  ffd0ff02de9da11e46ecd4209e3eee214ee3baa62f4889...           7.0
# 647   ffd8c9e83abe43cfef5919aef6988abfe0c62184727071...          76.0
# 590   ffd8c9e83abe43cfef5919aef6988abfe0c62184727071...          76.0
# 58    ffe861acba201a8165fef64d5bb44b41d61687c712ebff...         283.0
# 1118  ffe861acba201a8165fef64d5bb44b41d61687c712ebff...         283.0
#
#                                                    PUID  \
# 1043  x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/...
# 496   x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/...
# 1261                      x-fmt/387 x-fmt/387 x-fmt/387
# 406                       x-fmt/387 x-fmt/387 x-fmt/387
# 97    x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/...
# ...                                                 ...
# 1169  x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/...
# 647   fmt/353 fmt/353 fmt/353 fmt/353 fmt/353 fmt/35...
# 590   fmt/353 fmt/353 fmt/353 fmt/353 fmt/353 fmt/35...
# 58    x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/...
# 1118  x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/...
#
#                                               MIME_TYPE  \
# 1043  image/tiff image/tiff image/tiff image/tiff im...
# 496   image/tiff image/tiff image/tiff image/tiff im...
# 1261                   image/tiff image/tiff image/tiff
# 406                    image/tiff image/tiff image/tiff
# 97    image/tiff image/tiff image/tiff image/tiff im...
# ...                                                 ...
# 1169  image/tiff image/tiff image/tiff image/tiff im...
# 647   image/tiff image/tiff image/tiff image/tiff im...
# 590   image/tiff image/tiff image/tiff image/tiff im...
# 58    image/tiff image/tiff image/tiff image/tiff im...
# 1118  image/tiff image/tiff image/tiff image/tiff im...
#
#                                             FORMAT_NAME
# 1043  Exchangeable Image File Format (Uncompressed) ...
# 496   Exchangeable Image File Format (Uncompressed) ...
# 1261  Exchangeable Image File Format (Uncompressed) ...
# 406   Exchangeable Image File Format (Uncompressed) ...
# 97    Exchangeable Image File Format (Uncompressed) ...
# ...                                                 ...
# 1169  Exchangeable Image File Format (Uncompressed) ...
# 647   Tagged Image File Format Tagged Image File For...
# 590   Tagged Image File Format Tagged Image File For...
# 58    Exchangeable Image File Format (Uncompressed) ...
# 1118  Exchangeable Image File Format (Uncompressed) ...
#
# [902 rows x 16 columns]

# %% [markdown]
# Check a couple of partial hashes to see if an exact duplicate is found

# %%
DupFolders[DupFolders['SHA256_HASH'].str.contains("ffd0ff02de9da11e46ecd4209e3eee214ee3baa62f488")]
# Out:
#                                              PARENT_DIR PARENT_ID  \
# 446   \\P8L-NAS2\AAS Storage\Southeast Asia (ATG)\Th...
# 1169  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
#
#                                                     URI  \
# 446   file:///P8L-NAS2/AAS%20Storage/Southeast%20Asi...
# 1169  file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
#
#                                               FILE_PATH  \
# 446   \\P8L-NAS2\AAS Storage\Southeast Asia (ATG)\Th...
# 1169  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
#
#                                                    NAME  \
# 446   or.15749!12.13_f001r.tif or.15749!12.13_f001v....
# 1169  or.15749!12.13_f001r.tif or.15749!12.13_f001v....
#
#                                                  METHOD  \
# 446   Signature Signature Signature Signature Signat...
# 1169  Signature Signature Signature Signature Signat...
#
#                                   STATUS         SIZE  \
# 446   Done Done Done Done Done Done Done  657882208.0
# 1169  Done Done Done Done Done Done Done  657882208.0
#
#                                     TYPE                          EXT  \
# 446   File File File File File File File  tif tif tif tif tif tif tif
# 1169  File File File File File File File  tif tif tif tif tif tif tif
#
#                                           LAST_MODIFIED  \
# 446   2010-04-15T15:29:53+01:00 2010-04-15T15:30:05+...
# 1169  2010-04-15T15:29:53+01:00 2010-04-15T15:30:05+...
#
#                                             SHA256_HASH  FORMAT_COUNT  \
# 446   ffd0ff02de9da11e46ecd4209e3eee214ee3baa62f4889...           7.0
# 1169  ffd0ff02de9da11e46ecd4209e3eee214ee3baa62f4889...           7.0
#
#                                                    PUID  \
# 446   x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/...
# 1169  x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/...
#
#                                               MIME_TYPE  \
# 446   image/tiff image/tiff image/tiff image/tiff im...
# 1169  image/tiff image/tiff image/tiff image/tiff im...
#
#                                             FORMAT_NAME
# 446   Exchangeable Image File Format (Uncompressed) ...
# 1169  Exchangeable Image File Format (Uncompressed) ...

# %% [markdown]
# Happy that this methodology is sort of working, we can go on and list the folders that do not have an exact duplicate.

# %%
DupFolders[~DupFolders.duplicated(subset="SHA256_HASH",keep=False)].sort_values(by='SHA256_HASH')
# Out:
#                                              PARENT_DIR  \
# 497   \\P8L-NAS2\AAS Storage\Syriac (IT)\add_ms_1465...
# 1011  \\p12l-nas5\Hebrew MSS Digitisation\Hebrew MSS...
# 835   \\p12l-nas5\Hebrew MSS Digitisation\Hebrew MSS...
# 716   \\P8l-NAS2\Photographic Studio data\Sent to Bo...
# 104   \\P8L-NAS2\AAS Storage\AAS Legacy Images\or_12174
# ...                                                 ...
# 279   \\P8L-NAS2\AAS Storage\Persian (USW - MIW)\Or ...
# 736   \\P8l-NAS2\Photographic Studio data\Sent to Bo...
# 230   \\P8L-NAS2\AAS Storage\Microfiches and card ca...
# 346   \\P8L-NAS2\AAS Storage\Southeast Asia (ATG)\Gi...
# 1278  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
#
#                                               PARENT_ID  \
# 497                                                 ...
# 1011
# 835                                                 ...
# 716
# 104
# ...                                                 ...
# 279
# 736
# 230
# 346                                                 ...
# 1278                                                ...
#
#                                                     URI  \
# 497   file:///P8L-NAS2/AAS%20Storage/Syriac%20%28IT%...
# 1011  file:///p12l-nas5/Hebrew%20MSS%20Digitisation/...
# 835   file:///p12l-nas5/Hebrew%20MSS%20Digitisation/...
# 716   file:///P8l-NAS2/Photographic%20Studio%20data/...
# 104   file:///P8L-NAS2/AAS%20Storage/AAS%20Legacy%20...
# ...                                                 ...
# 279   file:///P8L-NAS2/AAS%20Storage/Persian%20%28US...
# 736   file:///P8l-NAS2/Photographic%20Studio%20data/...
# 230   file:///P8L-NAS2/AAS%20Storage/Microfiches%20a...
# 346   file:///P8L-NAS2/AAS%20Storage/Southeast%20Asi...
# 1278  file:///v19l-nas1/Greek%20MSS%20Phase%202%20Fo...
#
#                                               FILE_PATH  \
# 497   \\P8L-NAS2\AAS Storage\Syriac (IT)\add_ms_1465...
# 1011  \\p12l-nas5\Hebrew MSS Digitisation\Hebrew MSS...
# 835   \\p12l-nas5\Hebrew MSS Digitisation\Hebrew MSS...
# 716   \\P8l-NAS2\Photographic Studio data\Sent to Bo...
# 104   \\P8L-NAS2\AAS Storage\AAS Legacy Images\or_12...
# ...                                                 ...
# 279   \\P8L-NAS2\AAS Storage\Persian (USW - MIW)\Or ...
# 736   \\P8l-NAS2\Photographic Studio data\Sent to Bo...
# 230   \\P8L-NAS2\AAS Storage\Microfiches and card ca...
# 346   \\P8L-NAS2\AAS Storage\Southeast Asia (ATG)\Gi...
# 1278  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...
#
#                                                    NAME  \
# 497   add_ms_14654_f01r.tif add_ms_14654_f01v.tif ad...
# 1011  or_4726_fblefr.tif or_4726_fbrigv.tif or_4726_...
# 835   or_2884_f001r.tif or_2884_f001v.tif or_2884_f0...
# 716                         bl06_1_00.tif bl06_1_01.tif
# 104   or_12174_f001r.tif or_12174_f002r.tif or_12174...
# ...                                                 ...
# 279   Or.4769, f.1.tif Or.4769, f.10.tif Or.4769, f....
# 736   bl12_2_071.tif bl12_2_072.tif bl12_2_073.tif b...
# 230   Dardic_1.tif Dardic_2.tif Dardic_3.tif Dardic_...
# 346   Or_14844_f01r.tif Or_14844_f01v.tif Or_14844_f...
# 1278  or_14844_f001r.tif or_14844_f001v.tif or_14844...
#
#                                                  METHOD  \
# 497   Signature Signature Signature Signature Signat...
# 1011                      Signature Signature Signature
# 835   Signature Signature Signature Signature Signat...
# 716                                 Signature Signature
# 104   Signature Signature Signature Signature Signat...
# ...                                                 ...
# 279   Signature Signature Signature Signature Signat...
# 736   Signature Signature Signature Signature Signat...
# 230   Signature Signature Signature Signature Signat...
# 346   Signature Signature Signature Signature Signat...
# 1278  Signature Signature Signature Signature Signat...
#
#                                                  STATUS          SIZE  \
# 497   Done Done Done Done Done Done Done Done Done D...  1.270663e+10
# 1011                                     Done Done Done  1.381349e+08
# 835   Done Done Done Done Done Done Done Done Done D...  1.017208e+10
# 716                                           Done Done  8.521835e+07
# 104   Done Done Done Done Done Done Done Done Done D...  2.030349e+09
# ...                                                 ...           ...
# 279   Done Done Done Done Done Done Done Done Done D...  2.832473e+09
# 736   Done Done Done Done Done Done Done Done Done D...  1.270947e+09
# 230        Done Done Done Done Done Done Done Done Done  1.603940e+06
# 346   Done Done Done Done Done Done Done Done Done D...  1.345421e+10
# 1278  Done Done Done Done Done Done Done Done Done D...  1.336822e+10
#
#                                                    TYPE  \
# 497   File File File File File File File File File F...
# 1011                                     File File File
# 835   File File File File File File File File File F...
# 716                                           File File
# 104   File File File File File File File File File F...
# ...                                                 ...
# 279   File File File File File File File File File F...
# 736   File File File File File File File File File F...
# 230        File File File File File File File File File
# 346   File File File File File File File File File F...
# 1278  File File File File File File File File File F...
#
#                                                     EXT  \
# 497   tif tif tif tif tif tif tif tif tif tif tif ti...
# 1011                                        tif tif tif
# 835   tif tif tif tif tif tif tif tif tif tif tif ti...
# 716                                             tif tif
# 104   tif tif tif tif tif tif tif tif tif tif tif ti...
# ...                                                 ...
# 279   tif tif tif tif tif tif tif tif tif tif tif ti...
# 736   tif tif tif tif tif tif tif tif tif tif tif ti...
# 230                 tif tif tif tif tif tif tif tif tif
# 346   tif tif tif tif tif tif tif tif tif tif tif ti...
# 1278  tif tif tif tif tif tif tif tif tif tif tif ti...
#
#                                           LAST_MODIFIED  \
# 497   2013-03-28T13:28:34Z 2013-03-28T13:39:02Z 2013...
# 1011  2015-07-17T14:31:25+01:00 2015-07-17T14:31:30+...
# 835   2014-11-25T09:11:38Z 2014-11-25T09:11:43Z 2014...
# 716   2002-09-11T10:49:09+01:00 2002-09-11T10:53:52+...
# 104   2002-09-11T10:49:09+01:00 2002-09-11T10:53:52+...
# ...                                                 ...
# 279   2011-03-03T16:40:38Z 2011-03-03T16:40:38Z 2011...
# 736   2002-10-02T12:08:49+01:00 2002-10-02T12:13:27+...
# 230   2015-08-07T12:12:09+01:00 2015-08-07T12:12:10+...
# 346   2012-11-13T08:01:32Z 2012-11-13T08:15:52Z 2012...
# 1278  2012-11-13T09:01:32Z 2012-11-13T09:15:52Z 2012...
#
#                                             SHA256_HASH  FORMAT_COUNT  \
# 497   002615ad80eaf0f2d829580fe39daa2d2e42cc18d853bc...         145.0
# 1011  018128ac6e0154b3390d1cd21eb8a4b542bd6b3e169f91...           3.0
# 835   028cbbe30b86c2b4f2e1fae68e7a999a2073cdc8170c5e...         137.0
# 716   05d09d5ce96b47ef16483460711f80d997196168c2cbda...           2.0
# 104   05d09d5ce96b47ef16483460711f80d997196168c2cbda...          48.0
# ...                                                 ...           ...
# 279   fc87edbb263e618a50f820700ba8921b9de479f5eaa5a0...          32.0
# 736   fdc8e01cae1ee560945126d0094160c9dccb9764ba0255...          30.0
# 230   fdf1f19bafa5c78f8179bb322ad5f556365b3b48f0cc84...           9.0
# 346   fe38aa62ff02083facdfd586c2a4b8bb430b44f1cc2b2e...         152.0
# 1278  fe38aa62ff02083facdfd586c2a4b8bb430b44f1cc2b2e...         151.0
#
#                                                    PUID  \
# 497   x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/...
# 1011                      x-fmt/387 x-fmt/387 x-fmt/387
# 835   x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/...
# 716                                     fmt/353 fmt/353
# 104   fmt/353 fmt/353 fmt/353 fmt/353 fmt/353 fmt/35...
# ...                                                 ...
# 279   x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/...
# 736   fmt/353 fmt/353 fmt/353 fmt/353 fmt/353 fmt/35...
# 230   fmt/353 fmt/353 fmt/353 fmt/353 fmt/353 fmt/35...
# 346   x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/...
# 1278  x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/387 x-fmt/...
#
#                                               MIME_TYPE  \
# 497   image/tiff image/tiff image/tiff image/tiff im...
# 1011                   image/tiff image/tiff image/tiff
# 835   image/tiff image/tiff image/tiff image/tiff im...
# 716                               image/tiff image/tiff
# 104   image/tiff image/tiff image/tiff image/tiff im...
# ...                                                 ...
# 279   image/tiff image/tiff image/tiff image/tiff im...
# 736   image/tiff image/tiff image/tiff image/tiff im...
# 230   image/tiff image/tiff image/tiff image/tiff im...
# 346   image/tiff image/tiff image/tiff image/tiff im...
# 1278  image/tiff image/tiff image/tiff image/tiff im...
#
#                                             FORMAT_NAME
# 497   Exchangeable Image File Format (Uncompressed) ...
# 1011  Exchangeable Image File Format (Uncompressed) ...
# 835   Exchangeable Image File Format (Uncompressed) ...
# 716   Tagged Image File Format Tagged Image File Format
# 104   Tagged Image File Format Tagged Image File For...
# ...                                                 ...
# 279   Exchangeable Image File Format (Uncompressed) ...
# 736   Tagged Image File Format Tagged Image File For...
# 230   Tagged Image File Format Tagged Image File For...
# 346   Exchangeable Image File Format (Uncompressed) ...
# 1278  Exchangeable Image File Format (Uncompressed) ...
#
# [389 rows x 16 columns]

# %% [markdown]
# This shows 389 folders that do not contain exact duplicates (or potentially have a different number of files within the folder)

# %% [markdown]
# ## DAMPS ingest

# %% [markdown]
# ## To-do:
# Task - priority (all low)
# - ~Total number of tiff files in each folder?~
# - ~Total tiff file size in each folder?~
# - Identify all master and duplicate files(!) - in consultation with curators
# - Identify all DAR projects and numbers
# - Identify all sections responsible for folders
# - Identify reading direction for all folders (map from language field?)

# %% [markdown]
# Already added a column of 1s to the original Siegfried output for each file, so grouping the data by parent directory and summing shows the number of tiff files in each folder in the `FolderCount` column.
#
# The size in bytes is shown for each folder in the `SIZE` column.

# %%
parentFolderAnalysis=allData.groupby(['PARENT_DIR'],as_index=False).sum()
parentFolderAnalysis
# Out:
#                                              PARENT_DIR         ID  \
# 0     \\P12L-NAS5\Persian Digitisation\Grenville xli...     138075
# 1     \\P12L-NAS5\Persian Digitisation\IO Islamic 10...     131670
# 2     \\P12L-NAS5\Persian Digitisation\IO Islamic 12...    1733256
# 3     \\P12L-NAS5\Persian Digitisation\IO Islamic 13...     473424
# 4     \\P12L-NAS5\Persian Digitisation\IO Islamic 13...    2645175
# ...                                                 ...        ...
# 7348  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...  257674389
# 7349  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...   71730495
# 7350  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...   81032461
# 7351  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...  182004774
# 7352  \\v19l-nas1\Greek MSS Phase 2 Folder 2\Thai Ma...    1328571
#
#               SIZE  EXTENSION_MISMATCH  FORMAT_COUNT  FolderCount
# 0     4.396242e+10               False         525.0          525
# 1     3.393058e+10               False         209.0          209
# 2     1.283186e+11               False        1267.0         1267
# 3     2.354463e+10               False         224.0          224
# 4     1.518890e+11               False         975.0          975
# ...            ...                 ...           ...          ...
# 7348  1.285657e+10               False         194.0          194
# 7349  5.218129e+09               False          54.0           54
# 7350  5.501632e+09               False          61.0           61
# 7351  1.276355e+10               False         137.0          137
# 7352  1.183313e+08               False           1.0            1
#
# [7353 rows x 6 columns]
